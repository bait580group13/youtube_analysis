# %% [markdown]
# # DB Uploader (Group 13)

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# ### Youtube Videos (Table name: videos)
#
# | name | type | PK/FK | value | source | source_variable_name | meaning_and_purpose | use | sensitive_data |
# | ---- | ---- | ----- | ----- | ------ | -------------------- | ------------------- | --- | -------------- |
# | id | text | PK | n1WpP7iowLc | Youtube API | id.videoId |  The ID that YouTube uses to uniquely identify the channel that the video was uploaded to | Yes | No |
# | channel_id | Int | FK | 1 | Youtube API | id.channelId | The ID that YouTube uses to uniquely identify the channel that the video was uploaded to | Yes | No |
# | category_id | Int | FK | 10 | Youtube API | snippet.categoryId | The YouTube video category associated with the video | Yes | No |
# | title | Text | | Eminem - Walk On Water (Audio) ft. Beyonce | Youtube API | snippet.title | The video's title | Yes | No |
# | publish_time | Timestamp | | 2017-11-10T17:00:03.000Z | Youtube API | status.publishAt | The date and time when the video is scheduled to be published | Yes | No |
# | views | Int | | 17158579 | Youtube API | statistics.viewCount | The number of times the video has been viewed | Yes | No |
# | likes | Int | | 787425 | Youtube API | statistics.likeCount | The number of users who have indicated that they liked the video | Yes | No |
# | dislikes | Int | | 43420 | Youtube API | statistics.dislikeCount | The number of users who have indicated that they disliked the video | Yes | No |
# | comment_count | Int | | 125882 | Youtube API | statistics.commentCount | The number of comments for the video | Yes | No |
# | thumbnail_link | Text | | https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg | Youtube API | snippet.thumbnails.(key).url | The thumbnail image's URL | Yes | No |
# | comments_disabled | Boolean | | FALSE | Youtube API | Unknown | The boolean value indicating whether commenting is disabled | Yes | No |
# | ratings_disabled | Boolean | | FALSE | Youtube API | Unknown |  The boolean value indicating whether rating is disabled | Yes | No |
# | video_error_or_removed | Boolean | | FALSE | Youtube API | Unknown | The boolean value indicating whether video is disabled due to error or deletion | Yes | No |
# | description | Text | | Eminem's new track Walk on Water ft. Beyonce is available everywhere http://shady.sr/WOWEminem \nPlaylist Best of Eminem: https://goo.gl/AquNpo\nSubscribe for more: https://goo.gl/DxCrDV\n\nFor | Youtube API | snippet.description | The video's description | Yes | No |
#
#
# ### Channels (Table name: channels)
#
# | name | type | PK/FK | value | source | source_variable_name | meaning_and_purpose | use | sensitive_data |
# | ---- | ---- | ----- | ----- | ------ | -------------------- | ------------------- | --- | -------------- |
# | id | Int | PK | 1 | Youtube API | id.channelId | The ID that YouTube uses to uniquely identify the channel that the video was uploaded to | Yes | No |
# | title | Text | | EminemVEVO | Youtube API | snippet.title (Channels API) | The channel's title | Yes | No |
#
#
# ### Categories (Table name: categories)
#
# | name | type | PK/FK | value | source | source_variable_name | meaning_and_purpose | use | sensitive_data |
# | ---- | ---- | ----- | ----- | ------ | -------------------- | ------------------- | --- | -------------- |
# | id | Int | PK | 10 | Youtube API | snippet.categoryId | The YouTube video category associated with the video | Yes | No |
# | name | Text | | Music | Youtube API | snippet.title (VideoCategories API) | The video category's title | Yes | No |
#
#
# ###  Tags (Table name: tags)
#
# | name | type | PK/FK | value | source | source_variable_name | meaning_and_purpose | use | sensitive_data |
# | ---- | ---- | ----- | ----- | ------ | -------------------- | ------------------- | --- | -------------- |
# | id | Int | PK | 1 | None | None | The ID for identifying each tag/video combination | Yes | No |
# | name | Text | | Eminem "Walk" "On" "Water" "Aftermath/Shady/Interscope" "Rap" | Youtube API | snippet.tags[] | A list of keyword tags associated with the video | Yes | No |
#
#
# ### Videos and Tags (Table name: videos_tags)
#
# | name | type | PK/FK | value | source | source_variable_name | meaning_and_purpose | use | sensitive_data |
# | ---- | ---- | ----- | ----- | ------ | -------------------- | ------------------- | --- | -------------- |
# | id | Int | PK | 1 | None | None | The ID for identifying each tag/video combination | Yes | No |
# | video_id | Text | FK | n1WpP7iowLc | Youtube API | id.videoId | The ID that YouTube uses to uniquely identify the video | Yes | No |
# | tag_id | Int | FK | 1 | None | None | The ID for identifying each tag | Yes | No |

# %% [markdown]
# ## Library import and installation

# %%
# !pip install sqlalchemy

# %%
import requests
import json
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Data import from json file for category information

# %%
category = pd.read_json('CA_category_id.json')
list_i = category['items'].tolist()
parsing_items = pd.DataFrame(list_i)
list_s = parsing_items['snippet'].tolist()
parsing_snippet = pd.DataFrame(list_s)
parsing_snippet['category_id'] = parsing_items['id'].astype('int')
parsing_snippet.rename(columns = {'title':'category_name'}, inplace = True)
new_category = parsing_snippet[['category_id','category_name']]

# %%
country_list = ['US', 'RU', 'MX', 'KR', 'JP', 'IN', 'GB', 'FR', 'DE']
for c in country_list:
    category = pd.read_json(f'{c}_category_id.json')
    list_i = category['items'].tolist()
    parsing_items = pd.DataFrame(list_i)
    list_s = parsing_items['snippet'].tolist()
    parsing_snippet = pd.DataFrame(list_s)
    parsing_snippet['category_id'] = parsing_items['id'].astype('int')
    parsing_snippet.rename(columns = {'title':'category_name'}, inplace = True)
    new_category_countries = parsing_snippet[['category_id','category_name']]
    new_category = pd.concat([new_category, new_category_countries])
    new_category = new_category.drop_duplicates()
    
new_category = new_category.sort_values(by='category_id')
new_category
# Out:
#     category_id          category_name
# 0             1       Film & Animation
# 1             2       Autos & Vehicles
# 2            10                  Music
# 3            15         Pets & Animals
# 4            17                 Sports
# 5            18           Short Movies
# 6            19        Travel & Events
# 7            20                 Gaming
# 8            21          Videoblogging
# 9            22         People & Blogs
# 10           23                 Comedy
# 11           24          Entertainment
# 12           25        News & Politics
# 13           26          Howto & Style
# 14           27              Education
# 15           28   Science & Technology
# 16           29  Nonprofits & Activism
# 16           30                 Movies
# 17           31        Anime/Animation
# 18           32       Action/Adventure
# 19           33               Classics
# 20           34                 Comedy
# 21           35            Documentary
# 22           36                  Drama
# 23           37                 Family
# 24           38                Foreign
# 25           39                 Horror
# 26           40         Sci-Fi/Fantasy
# 27           41               Thriller
# 28           42                 Shorts
# 29           43                  Shows
# 30           44               Trailers

# %% [markdown]
# ## Data Import from csv files about trending videos in differnt countries

# %%
# As we don't have translation ability for foreign languages, we decided to do not include the data from the countries not using English

videos_ca = pd.read_csv('CAvideos.csv')
#videos['country'] = 'CA'

# %%
#country_list = ['US', 'RU', 'MX', 'KR', 'JP', 'IN', 'GB', 'FR', 'DE']
country_list = ['US', 'GB']
for c in country_list:
    videos_countries = pd.read_csv(f'{c}videos.csv', encoding = "ISO-8859-1")
    print(videos_countries.shape)
    videos_ca = pd.concat([videos_ca, videos_countries])
videos_concat = videos_ca
videos_concat
# Out:
# (40949, 16)
# (38916, 16)
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                               I Dare You: GOING BALD!?
# 4            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# 38913                 Anne-Marie - 2002 [Official Video]
# 38914  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 38915  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                  channel_title  category_id              publish_time  \
# 0                   EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1                    iDubbbzTV           23  2017-11-13T17:00:00.000Z
# 2                 Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3                     nigahiga           24  2017-11-12T18:01:41.000Z
# 4                   Ed Sheeran           10  2017-11-09T11:04:14.000Z
# ...                        ...          ...                       ...
# 38911      EnriqueIglesiasVEVO           10  2018-05-09T07:00:01.000Z
# 38912          Jacob Sartorius           10  2018-05-11T17:09:16.000Z
# 38913               Anne-Marie           10  2018-05-08T11:05:08.000Z
# 38914  Eurovision Song Contest           24  2018-05-08T20:32:32.000Z
# 38915           SuperDuperKyle           10  2018-05-11T04:06:35.000Z
#
#                                                     tags     views    likes  \
# 0      Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1      plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4      edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
# ...                                                  ...       ...      ...
# 38911  Enrique Iglesias feat. Pitbull|"MOVE TO MIAMI"...  25066952   268088
# 38912  jacob sartorius|"jacob"|"up with it"|"jacob sa...   1492219    61998
# 38913  anne|"marie"|"anne-marie"|"2002"|"two thousand...  29641412   394830
# 38914  Eurovision Song Contest|"2018"|"Lisbon"|"Cypru...  14317515   151870
# 38915  Kyle|"SuperDuperKyle"|"Ikuyo"|"2 Chainz"|"Soph...    607552    18271
#
#        dislikes  comment_count  \
# 0         43420         125882
# 1          1688          13030
# 2          5339           8181
# 3          1989          17518
# 4         21082          85067
# ...         ...            ...
# 38911     12783           9933
# 38912     13781          24330
# 38913      8892          19988
# 38914     45875          26766
# 38915       274           1423
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg              False
# 1      https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# 4      https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg              False
# ...                                               ...                ...
# 38911  https://i.ytimg.com/vi/l884wKofd54/default.jpg              False
# 38912  https://i.ytimg.com/vi/IP8k2xkhOdI/default.jpg              False
# 38913  https://i.ytimg.com/vi/Il-an3K9pjg/default.jpg              False
# 38914  https://i.ytimg.com/vi/-DRsfNObKIQ/default.jpg              False
# 38915  https://i.ytimg.com/vi/4YFo4bdMO8Q/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 38911             False                   False
# 38912             False                   False
# 38913             False                   False
# 38914             False                   False
# 38915             False                   False
#
#                                              description
# 0      Eminem's new track Walk on Water ft. Beyoncé i...
# 1      STill got a lot of packages. Probably will las...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      I know it's been a while since we did this sho...
# 4      🎧: https://ad.gt/yt-perfect\n💰: https://atlant...
# ...                                                  ...
# 38911  NEW SONG - MOVE TO MIAMI feat. Pitbull (Click ...
# 38912  THE OFFICIAL UP WITH IT MUSIC VIDEO!Get my new...
# 38913  Get 2002 by Anne-Marie HERE â¶ http://ad.gt/2...
# 38914  Eleni Foureira represented Cyprus at the first...
# 38915  Debut album 'Light of Mine' out now: http://ky...
#
# [120746 rows x 16 columns]

# %%
videos_concat['category_id'].unique(), len(videos_concat['category_id'].unique())
# Out:
# (array([10, 23, 24, 25, 22, 26,  1, 28, 20, 17, 29, 15, 19,  2, 27, 43, 30]),
#  17)

# %%
videos_concat.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %% [markdown]
# ## Master dataset before normalization

# %%
# making master dataset by merging category and video datasets

videos_merged = videos_concat.merge(new_category, how = 'left', on = 'category_id')
videos_merged.to_csv('videos_merged.csv')
videos_merged
# Out:
#            video_id trending_date  \
# 0       n1WpP7iowLc      17.14.11
# 1       0dBIkQ4Mz1M      17.14.11
# 2       5qpjK5DgCt4      17.14.11
# 3       d380meD0W0M      17.14.11
# 4       2Vv-BfVoq4g      17.14.11
# ...             ...           ...
# 120741  l884wKofd54      18.14.06
# 120742  IP8k2xkhOdI      18.14.06
# 120743  Il-an3K9pjg      18.14.06
# 120744  -DRsfNObKIQ      18.14.06
# 120745  4YFo4bdMO8Q      18.14.06
#
#                                                     title  \
# 0              Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                           PLUSH - Bad Unboxing Fan Mail
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                                I Dare You: GOING BALD!?
# 4             Ed Sheeran - Perfect (Official Music Video)
# ...                                                   ...
# 120741  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 120742  Jacob Sartorius - Up With It (Official Music V...
# 120743                 Anne-Marie - 2002 [Official Video]
# 120744  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 120745  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                   channel_title  category_id              publish_time  \
# 0                    EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1                     iDubbbzTV           23  2017-11-13T17:00:00.000Z
# 2                  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3                      nigahiga           24  2017-11-12T18:01:41.000Z
# 4                    Ed Sheeran           10  2017-11-09T11:04:14.000Z
# ...                         ...          ...                       ...
# 120741      EnriqueIglesiasVEVO           10  2018-05-09T07:00:01.000Z
# 120742          Jacob Sartorius           10  2018-05-11T17:09:16.000Z
# 120743               Anne-Marie           10  2018-05-08T11:05:08.000Z
# 120744  Eurovision Song Contest           24  2018-05-08T20:32:32.000Z
# 120745           SuperDuperKyle           10  2018-05-11T04:06:35.000Z
#
#                                                      tags     views    likes  \
# 0       Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1       plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2       racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3       ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4       edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
# ...                                                   ...       ...      ...
# 120741  Enrique Iglesias feat. Pitbull|"MOVE TO MIAMI"...  25066952   268088
# 120742  jacob sartorius|"jacob"|"up with it"|"jacob sa...   1492219    61998
# 120743  anne|"marie"|"anne-marie"|"2002"|"two thousand...  29641412   394830
# 120744  Eurovision Song Contest|"2018"|"Lisbon"|"Cypru...  14317515   151870
# 120745  Kyle|"SuperDuperKyle"|"Ikuyo"|"2 Chainz"|"Soph...    607552    18271
#
#         dislikes  comment_count  \
# 0          43420         125882
# 1           1688          13030
# 2           5339           8181
# 3           1989          17518
# 4          21082          85067
# ...          ...            ...
# 120741     12783           9933
# 120742     13781          24330
# 120743      8892          19988
# 120744     45875          26766
# 120745       274           1423
#
#                                         thumbnail_link  comments_disabled  \
# 0       https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg              False
# 1       https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg              False
# 2       https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3       https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# 4       https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg              False
# ...                                                ...                ...
# 120741  https://i.ytimg.com/vi/l884wKofd54/default.jpg              False
# 120742  https://i.ytimg.com/vi/IP8k2xkhOdI/default.jpg              False
# 120743  https://i.ytimg.com/vi/Il-an3K9pjg/default.jpg              False
# 120744  https://i.ytimg.com/vi/-DRsfNObKIQ/default.jpg              False
# 120745  https://i.ytimg.com/vi/4YFo4bdMO8Q/default.jpg              False
#
#         ratings_disabled  video_error_or_removed  \
# 0                  False                   False
# 1                  False                   False
# 2                  False                   False
# 3                  False                   False
# 4                  False                   False
# ...                  ...                     ...
# 120741             False                   False
# 120742             False                   False
# 120743             False                   False
# 120744             False                   False
# 120745             False                   False
#
#                                               description  category_name
# 0       Eminem's new track Walk on Water ft. Beyoncé i...          Music
# 1       STill got a lot of packages. Probably will las...         Comedy
# 2       WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...         Comedy
# 3       I know it's been a while since we did this sho...  Entertainment
# 4       🎧: https://ad.gt/yt-perfect\n💰: https://atlant...          Music
# ...                                                   ...            ...
# 120741  NEW SONG - MOVE TO MIAMI feat. Pitbull (Click ...          Music
# 120742  THE OFFICIAL UP WITH IT MUSIC VIDEO!Get my new...          Music
# 120743  Get 2002 by Anne-Marie HERE â¶ http://ad.gt/2...          Music
# 120744  Eleni Foureira represented Cyprus at the first...  Entertainment
# 120745  Debut album 'Light of Mine' out now: http://ky...          Music
#
# [120746 rows x 17 columns]

# %%
videos_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120746 entries, 0 to 120745
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   video_id                120746 non-null  object
#  1   trending_date           120746 non-null  object
#  2   title                   120746 non-null  object
#  3   channel_title           120746 non-null  object
#  4   category_id             120746 non-null  int64
#  5   publish_time            120746 non-null  object
#  6   tags                    120746 non-null  object
#  7   views                   120746 non-null  int64
#  8   likes                   120746 non-null  int64
#  9   dislikes                120746 non-null  int64
#  10  comment_count           120746 non-null  int64
#  11  thumbnail_link          120746 non-null  object
#  12  comments_disabled       120746 non-null  bool
#  13  ratings_disabled        120746 non-null  bool
#  14  video_error_or_removed  120746 non-null  bool
#  15  description             118268 non-null  object
#  16  category_name           120746 non-null  object
# dtypes: bool(3), int64(5), object(9)
# memory usage: 14.2+ MB

# %%
videos_merged['video_id'].value_counts()
# Out:
# 8h--kFui1JA    70
# VYOjWnS4cMY    69
# vjSohj-Iclc    65
# l884wKofd54    64
# UUkn-enk2RU    64
#                ..
# EX5e_DvmWF8     1
# C8NC80CGnbA     1
# 8sRu_Xg3laE     1
# jOc5wQYVLUY     1
# 14G7Qw5DC9M     1
# Name: video_id, Length: 30318, dtype: int64

# %%
videos_merged.query("video_id == '6ZfuNTqbHE8'")
# Out:
#           video_id trending_date  \
# 3198   6ZfuNTqbHE8      17.30.11
# 3398   6ZfuNTqbHE8      17.01.12
# 3598   6ZfuNTqbHE8      17.02.12
# 3798   6ZfuNTqbHE8      17.03.12
# 3998   6ZfuNTqbHE8      17.04.12
# 4202   6ZfuNTqbHE8      17.05.12
# 4451   6ZfuNTqbHE8      17.06.12
# 4699   6ZfuNTqbHE8      17.07.12
# 44081  6ZfuNTqbHE8      17.30.11
# 44281  6ZfuNTqbHE8      17.01.12
# 44486  6ZfuNTqbHE8      17.02.12
# 44699  6ZfuNTqbHE8      17.03.12
# 44924  6ZfuNTqbHE8      17.04.12
# 45157  6ZfuNTqbHE8      17.05.12
# 45395  6ZfuNTqbHE8      17.06.12
# 45624  6ZfuNTqbHE8      17.07.12
# 45878  6ZfuNTqbHE8      17.08.12
# 85028  6ZfuNTqbHE8      17.30.11
# 85228  6ZfuNTqbHE8      17.01.12
# 85426  6ZfuNTqbHE8      17.02.12
# 85626  6ZfuNTqbHE8      17.03.12
# 85829  6ZfuNTqbHE8      17.04.12
# 86061  6ZfuNTqbHE8      17.05.12
# 86280  6ZfuNTqbHE8      17.06.12
# 86496  6ZfuNTqbHE8      17.07.12
# 86731  6ZfuNTqbHE8      17.08.12
# 86954  6ZfuNTqbHE8      17.09.12
# 87162  6ZfuNTqbHE8      17.10.12
# 87365  6ZfuNTqbHE8      17.11.12
There was an ideaâ¦ Avengers: Infinity War. I...  Entertainment

# %%
# Removing duplicate videos in the master dataset

videos_merged = videos_merged.drop_duplicates(['video_id'])
videos_merged.query("video_id == '6ZfuNTqbHE8'")
# Out:
#           video_id trending_date  \
# 88021  6ZfuNTqbHE8      17.14.12
#
#                                                    title  \
# 88021  Marvel Studios' Avengers: Infinity War Officia...
#
#               channel_title  category_id              publish_time  \
# 88021  Marvel Entertainment           24  2017-11-29T13:26:24.000Z
#
#                                                     tags      views    likes  \
# 88021  marvel|"comics"|"comic books"|"nerdy"|"geeky"|...  100672931  2701353
#
#        dislikes  comment_count  \
# 88021     56313         368739
#
#                                        thumbnail_link  comments_disabled  \
# 88021  https://i.ytimg.com/vi/6ZfuNTqbHE8/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 88021             False                   False
#
#                                              description  category_name
# 88021  There was an ideaâ¦ Avengers: Infinity War. I...  Entertainment

# %%
videos_merged['video_id'].value_counts().sort_values(ascending = False)
# Out:
# _I_D_8Z4sJE    1
# au2n7VVGv_c    1
# xpVfcZ0ZcFM    1
# ffxKSjUwKdU    1
# zEf423kYfqk    1
#               ..
# zeQaJGkFyqQ    1
# dQMZLXaa1L8    1
# -JVITToppE0    1
# 0c8C0p1WS7k    1
# y6KYFcta4SE    1
# Name: video_id, Length: 30318, dtype: int64

# %% [markdown]
# ## Creating dataframe for each table after nomalization

# %%
# DF for videos_tags and tags table

video_tags_original = videos_merged[['video_id','tags']]
video_list = video_tags_original['video_id'].unique()

video_tags = []

i = 0
for v in video_list:
    tags = video_tags_original.query("video_id == "+"'"+v+"'")['tags'].to_list()
    for t in tags:
        tlist = t.split('|')
        for tl in tlist:
            vt = (i, v, re.sub(r"[^a-zA-Z]","",tl))
            video_tags.append(vt)
            i+=1
            
video_tags = pd.DataFrame(video_tags, columns = ['id', 'video_id', 'tag'])

tags = video_tags['tag'].unique()
tags = pd.DataFrame({'tag_id': range(1, len(tags)+1), 'tag' : tags})

video_tags = video_tags.merge(tags, how = 'left', on = 'tag')
video_tags = video_tags[['id','video_id','tag_id']]
video_tags
# Out:
#             id     video_id  tag_id
# 0            0  _I_D_8Z4sJE       1
# 1            1  _I_D_8Z4sJE       2
# 2            2  _I_D_8Z4sJE       3
# 3            3  _I_D_8Z4sJE       4
# 4            4  _I_D_8Z4sJE       5
# ...        ...          ...     ...
# 587891  587891  y6KYFcta4SE  160268
# 587892  587892  y6KYFcta4SE   23417
# 587893  587893  y6KYFcta4SE   17332
# 587894  587894  y6KYFcta4SE    4080
# 587895  587895  y6KYFcta4SE  160269
#
# [587896 rows x 3 columns]

# %%
# DF for channels table

channels_original = videos_merged['channel_title']
channels = channels_original.unique()
channels = pd.DataFrame({'channel_id': range(1, len(channels)+1), 'channel_title' : channels})
channels
# Out:
#       channel_id                              channel_title
# 0              1                                 NickyJamTV
# 1              2                              Flow La Movie
# 2              3                                  Bad Bunny
# 3              4                                      Ozuna
# 4              5                        ChildishGambinoVEVO
# ...          ...                                        ...
# 6905        6906  University of Rochester EEOC Complainants
# 6906        6907       OjO Commuter Scooter by OjO Electric
# 6907        6908                            90s Commercials
# 6908        6909                           Palo Alto Online
# 6909        6910                              GoDucksdotcom
#
# [6910 rows x 2 columns]

# %%
videos_merged = videos_merged.merge(channels, how = 'left', on = 'channel_title')
videos_merged
# Out:
#           video_id trending_date  \
default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 30313             False                   False
# 30314             False                   False
# 30315             False                   False
# 30316             False                   False
# 30317             False                   False
#
#                                              description    category_name  \
# 0      Disponible en tu plataforma preferida:\nhttps:...            Music
# 1      Flow La Movie Presenta - Te BotÃ© Remix - Casp...            Music
# 2      Bad Bunny - Amorfoda | Video Oficial\n\n-Click...            Music
# 3      DESCARGA Odisea Aqui: http://apple.co/2vX00sT\...            Music
# 4      âThis is Americaâ by Childish Gambino http...            Music
# ...                                                  ...              ...
# 30313                          Anyone have one of those?        Education
# 30314  Three deputies and one police officer were sho...  News & Politics
# 30315  Artwork Forge II - an art installation created...           Sports
# 30316  Coach Taggart addresses the media ahead of the...           Sports
# 30317  Kentucky Gov. Matt Bevin confirmed there was a...  News & Politics
#
#        channel_id
# 0               1
# 1               2
# 2               3
# 3               4
# 4               5
# ...           ...
# 30313        6908
# 30314        3475
# 30315        6909
# 30316        6910
# 30317        5662
#
# [30318 rows x 18 columns]

# %%
# DF for tags table

tags
# Out:
#         tag_id                       tag
# 0            1                  BadBunny
# 1            2                  Amorfoda
# 2            3                      Dura
# 3            4               DaddyYankee
# 4            5                     Ozuna
# ...        ...                       ...
# 160264  160265             AutzenStadium
# 160265  160266                      NIKE
# 160266  160267  marshallcountyhighschool
# 160267  160268                  fatality
# 160268  160269         governormattbevin
#
# [160269 rows x 2 columns]

# %%
videos_merged.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'category_name', 'channel_id'],
#       dtype='object')

# %%
# DF for videos table

videos = videos_merged[['video_id', 'title', 'channel_id', 'category_id',
       'publish_time', 'views', 'likes', 'dislikes', 'comment_count',
       'thumbnail_link', 'comments_disabled', 'ratings_disabled',
       'video_error_or_removed', 'description']]
videos
# Out:
#           video_id                                              title  \
# 0      _I_D_8Z4sJE  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...
# 1      9jI-z9QN6g8  Te Bote Remix - Casper, Nio GarcÃ­a, Darell, N...
# 2      kLpH1nSLJSs               Bad Bunny - Amorfoda | Video Oficial
# 3      wfWkmURBNv8           Ozuna x Romeo Santos - El Farsante Remix
# 4      VYOjWnS4cMY  Childish Gambino - This Is America (Official V...
# ...            ...                                                ...
# 30313  qg0GdM60syI             Huffy Metaloid Bicycle Commercial 1997
# 30314  zeQaJGkFyqQ     Raw: 3 South Carolina Deputies, 1 Officer Shot
# 30315  dQMZLXaa1L8                                      Artwork Forge
# 30316  -JVITToppE0      Coach Taggart Monday Presser Ahead of Arizona
# 30317  y6KYFcta4SE   1 dead, others injured after Ky. school shooting
#
#        channel_id  category_id              publish_time      views    likes  \
# 0               1           10  2018-03-02T05:00:19.000Z  424538912  2818771
# 1               2           10  2018-04-11T22:00:00.000Z  337621571  2581961
# 2               3           10  2018-02-15T00:00:03.000Z  328860380  3823879
# 3               4           10  2018-01-30T15:00:05.000Z  288811992  1618180
# 4               5           10  2018-05-06T04:00:07.000Z  259721696  5444541
# ...           ...          ...                       ...        ...      ...
# 30313        6908           27  2017-03-31T21:46:53.000Z        773        2
# 30314        3475           25  2018-01-16T12:16:44.000Z        748        9
# 30315        6909           17  2018-01-10T23:53:56.000Z        745        1
# 30316        6910           17  2017-11-13T20:41:45.000Z        704       10
# 30317        5662           25  2018-01-23T15:30:01.000Z        559        9
#
#        dislikes  comment_count  \
# 0        149275          99380
# 1        166549         113564
# 2        215530         225216
# 3        151147          67506
# 4        379862         553371
# ...         ...            ...
# 30313         0              0
# 30314         0              0
# 30315         0              0
# 30316         2              5
# 30317         0              4
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/_I_D_8Z4sJE/default.jpg              False
# 1      https://i.ytimg.com/vi/9jI-z9QN6g8/default.jpg              False
# 2      https://i.ytimg.com/vi/kLpH1nSLJSs/default.jpg              False
# 3      https://i.ytimg.com/vi/wfWkmURBNv8/default.jpg              False
# 4      https://i.ytimg.com/vi/VYOjWnS4cMY/default.jpg              False
# ...                                               ...                ...
# 30313  https://i.ytimg.com/vi/qg0GdM60syI/default.jpg              False
# 30314  https://i.ytimg.com/vi/zeQaJGkFyqQ/default.jpg               True
# 30315  https://i.ytimg.com/vi/dQMZLXaa1L8/default.jpg              False
# 30316  https://i.ytimg.com/vi/-JVITToppE0/default.jpg              False
# 30317  https://i.ytimg.com/vi/y6KYFcta4SE/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 30313             False                   False
# 30314             False                   False
# 30315             False                   False
# 30316             False                   False
# 30317             False                   False
#
#                                              description
# 0      Disponible en tu plataforma preferida:\nhttps:...
# 1      Flow La Movie Presenta - Te BotÃ© Remix - Casp...
# 2      Bad Bunny - Amorfoda | Video Oficial\n\n-Click...
# 3      DESCARGA Odisea Aqui: http://apple.co/2vX00sT\...
# 4      âThis is Americaâ by Childish Gambino http...
# ...                                                  ...
# 30313                          Anyone have one of those?
# 30314  Three deputies and one police officer were sho...
# 30315  Artwork Forge II - an art installation created...
# 30316  Coach Taggart addresses the media ahead of the...
# 30317  Kentucky Gov. Matt Bevin confirmed there was a...
#
# [30318 rows x 14 columns]

# %%
# DF for categories table

categories = new_category
categories
# Out:
#     category_id          category_name
# 0             1       Film & Animation
# 1             2       Autos & Vehicles
# 2            10                  Music
# 3            15         Pets & Animals
# 4            17                 Sports
# 5            18           Short Movies
# 6            19        Travel & Events
# 7            20                 Gaming
# 8            21          Videoblogging
# 9            22         People & Blogs
# 10           23                 Comedy
# 11           24          Entertainment
# 12           25        News & Politics
# 13           26          Howto & Style
# 14           27              Education
# 15           28   Science & Technology
# 16           29  Nonprofits & Activism
# 16           30                 Movies
# 17           31        Anime/Animation
# 18           32       Action/Adventure
# 19           33               Classics
# 20           34                 Comedy
# 21           35            Documentary
# 22           36                  Drama
# 23           37                 Family
# 24           38                Foreign
# 25           39                 Horror
# 26           40         Sci-Fi/Fantasy
# 27           41               Thriller
# 28           42                 Shorts
# 29           43                  Shows
# 30           44               Trailers

# %%
# DF for trending video list in Canada for future use 
# (we didn't use this table for our analysis, therefore, this table is not included in ERD and data dictionary)

videos_ca = pd.read_csv('CAvideos.csv').sort_values(by = 'views', ascending = False)

ca_videos = videos_ca['video_id'].unique()
ca_videos = pd.DataFrame({'id': range(1, len(ca_videos)+1), 'video_id' : ca_videos})
ca_videos
# Out:
#           id     video_id
# 0          1  FlsCjmMhFmw
# 1          2  VYOjWnS4cMY
# 2          3  6ZfuNTqbHE8
# 3          4  7C2z4GqqS5E
# 4          5  _I_D_8Z4sJE
# ...      ...          ...
# 24422  24423  q-_6-i2kNoE
# 24423  24424  xuLevcMO3BI
# 24424  24425  nqR7jkb3ehM
# 24425  24426  0ayARJdf7I4
# 24426  24427  CGv_PLrWArs
#
# [24427 rows x 2 columns]

# %%
# DF for trending video list in the US for future use 
# (we didn't use this table for our analysis, therefore, this table is not included in ERD and data dictionary)

videos_us = pd.read_csv('USvideos.csv').sort_values(by = 'views', ascending = False)

us_videos = videos_us['video_id'].unique()
us_videos = pd.DataFrame({'id': range(1, len(us_videos)+1), 'video_id' : us_videos})
us_videos
# Out:
#         id     video_id
# 0        1  VYOjWnS4cMY
# 1        2  FlsCjmMhFmw
# 2        3  ffxKSjUwKdU
# 3        4  zEf423kYfqk
# 4        5  7C2z4GqqS5E
# ...    ...          ...
# 6346  6347  qg0GdM60syI
# 6347  6348  zeQaJGkFyqQ
# 6348  6349  dQMZLXaa1L8
# 6349  6350  -JVITToppE0
# 6350  6351  y6KYFcta4SE
#
# [6351 rows x 2 columns]

# %%
# DF for trending video list in Great Britain for future use
# (we didn't use this table for our analysis, therefore, this table is not included in ERD and data dictionary)

videos_gb = pd.read_csv('GBvideos.csv').sort_values(by = 'views', ascending = False)

gb_videos = videos_gb['video_id'].unique()
gb_videos = pd.DataFrame({'id': range(1, len(gb_videos)+1), 'video_id' : gb_videos})
gb_videos
# Out:
#         id     video_id
# 0        1  _I_D_8Z4sJE
# 1        2  9jI-z9QN6g8
# 2        3  kLpH1nSLJSs
# 3        4  wfWkmURBNv8
# 4        5  VYOjWnS4cMY
# ...    ...          ...
# 3267  3268  NXin9D2Nc10
# 3268  3269  au3S8F08v54
# 3269  3270  NcVxrr_q3Hw
# 3270  3271  vPsic3dEndc
# 3271  3272  n26wtR-OFr8
#
# [3272 rows x 2 columns]

# %% [markdown]
# ## Table upload to RDS by using SQLalchemy

# %%
# DB connection

import os
import psycopg2

from dotenv import load_dotenv
load_dotenv()

conString = {'host':os.environ.get('DB_HOST'),
             'dbname':os.environ.get('DB_NAME'),
             'user':os.environ.get('DB_USER'),
             'password':os.environ.get('DB_PASS'),
             'port':os.environ.get('DB_PORT')}

conn = psycopg2.connect(**conString)
cur = conn.cursor()

# %%
# Creating SCHEMA for tables

query = """CREATE SCHEMA IF NOT EXISTS test;"""
cur.execute(query)
conn.commit()

# %%
# Data samples for categories table

print(categories.columns)
categories.head(3)
# Out:
# Index(['category_id', 'category_name'], dtype='object')
#    category_id     category_name
# 0            1  Film & Animation
# 1            2  Autos & Vehicles
# 2           10             Music

# %%
# creating categories table and uploading data by using SQLalchemy

import sqlalchemy
from sqlalchemy import create_engine

#sqlalchemy = sqlalchemy
engine = create_engine(f"postgresql+psycopg2://{conString['user']}:{conString['password']}@{conString['host']}/{conString['dbname']}")

dtypesql = {'category_id':sqlalchemy.types.INT, 
          'category_name':sqlalchemy.types.TEXT 
}

categories.to_sql(name='categories', schema = 'test', con=engine, if_exists='fail', index=False, dtype=dtypesql)

# %%
# Setting required constraints for the table(PK, FK, and any other constraints)

conn.rollback()
cur.execute("""ALTER TABLE test.categories
                ADD CONSTRAINT categories_PK
                PRIMARY KEY (category_id)
                ;""")
conn.commit()

cur.execute("""ALTER TABLE test.categories ALTER column category_id SET NOT NULL;""")
conn.commit()

# %%
conn.rollback()
query = """SELECT * FROM test.categories;"""
cur.execute(query)
row = cur.fetchall()
print(row)
# Out:
# [(1, 'Film & Animation'), (2, 'Autos & Vehicles'), (10, 'Music'), (15, 'Pets & Animals'), (17, 'Sports'), (18, 'Short Movies'), (19, 'Travel & Events'), (20, 'Gaming'), (21, 'Videoblogging'), (22, 'People & Blogs'), (23, 'Comedy'), (24, 'Entertainment'), (25, 'News & Politics'), (26, 'Howto & Style'), (27, 'Education'), (28, 'Science & Technology'), (29, 'Nonprofits & Activism'), (30, 'Movies'), (31, 'Anime/Animation'), (32, 'Action/Adventure'), (33, 'Classics'), (34, 'Comedy'), (35, 'Documentary'), (36, 'Drama'), (37, 'Family'), (38, 'Foreign'), (39, 'Horror'), (40, 'Sci-Fi/Fantasy'), (41, 'Thriller'), (42, 'Shorts'), (43, 'Shows'), (44, 'Trailers')]

# %%
# Data samples for channels table

print(channels.columns)
channels.head(3)
# Out:
# Index(['channel_id', 'channel_title'], dtype='object')
#    channel_id  channel_title
# 0           1     NickyJamTV
# 1           2  Flow La Movie
# 2           3      Bad Bunny

# %%
# creating channels table and uploading data by using SQLalchemy

dtypesql = {'channel_id':sqlalchemy.types.INT, 
          'channel_title':sqlalchemy.types.TEXT 
}

channels.to_sql(name='channels', schema = 'test', con=engine, if_exists='fail', index=False, dtype=dtypesql)

# %%
# Setting required constraints for the table(PK, FK, and any other constraints)

conn.rollback()
cur.execute("""ALTER TABLE test.channels
                ADD CONSTRAINT channels_PK
                PRIMARY KEY (channel_id)
                ;""")
conn.commit()

cur.execute("""ALTER TABLE test.channels ALTER column channel_id SET NOT NULL;""")
conn.commit()

# %%
conn.rollback()
query = """SELECT * FROM test.channels;"""
cur.execute(query)
row = cur.fetchall()
print(row)
# Out:
# [(1, 'NickyJamTV'), (2, 'Flow La Movie'), (3, 'Bad Bunny'), (4, 'Ozuna'), (5, 'ChildishGambinoVEVO'), (6, 'DrakeVEVO'), (7, 'ArianaGrandeVevo'), (8, 'BeckyGVEVO'), (9, 'YouTube Spotlight'), (10, 'Daddy Yankee'), (11, 'LuisFonsiVEVO'), (12, 'Ed Sheeran'), (13, 'TheWeekndVEVO'), (14, 'ibighit'), (15, 'TaylorSwiftVEVO'), (16, 'PostMaloneVEVO'), (17, 'Marvel Entertainment'), (18, 'MigosVEVO'), (19, 'CalvinHarrisVEVO'), (20, 'jypentertainment'), (21, 'RomeoSantosVEVO'), (22, 'Cardi B'), (23, 'SebastianYatraVEVO'), (24, 'Pina Records'), (25, 'Bruno Mars'), (26, 'EnriqueIglesiasVEVO'), (27, 'MalumaVEVO'), (28, 'Maroon5VEVO'), (29, 'ShawnMendesVEVO'), (30, 'WORLDSTARHIPHOP'), (31, 'shakiraVEVO'), (32, 'Dua Lipa'), (33, 'jbalvinVEVO'), (34, 'xxxtentacion'), (35, 'BlocBoy JB'), (36, 'GEazyMusicVEVO'), (37, '21SavageVEVO'), (38, 'KendrickLamarVEVO'), (39, 'DavidBisbalVEVO'), (40, 'Post Malone'), (41, 'EminemVEVO'), (42, 'Update Music TV'), (43, 'Kylie Jenner'), (44, 'ZaynVEVO'), (45, 'Sony Pictures Entertainment'), (46, 'Warner Music'), (47, 'ChainsmokersVEVO'), (48, 'KarolGVEVO'), (49, 'Selena Gomez'), (50, '5-Minute Crafts'), (51, 'Lucas Lucco'), (52, 'ChrisJedayVE
¼\x80ì\x9d´)'), (152, 'TWICE JAPAN OFFICIAL YouTube Channel'), (153, 'KygoOfficialVEVO'), (154, 'Risingsunrsf'), (155, 'TravisScottVEVO'), (156, 'Jaden Smith'), (157, 'BalajiMotionPictures'), (158, 'FilmSelect Trailer'), (159, 'LIL UZI VERT'), (160, 'Inside Edition'), (161, 'BackstreetBoysVEVO'), (162, 'Young Thug'), (163, 'chayanneVEVO'), (164, 'The Action Lab'), (165, 'NachoVEVO'), (166, 'Home Bollywud'), (167, 'Saad Lamjarred | سعد لمجرد'), (168, 'Samsung Mobile USA'), (169, 'GalacticFusion ...

# %%
# Data samples for tags table

print(tags.columns)
tags.head(3)
# Out:
# Index(['tag_id', 'tag'], dtype='object')
#    tag_id       tag
# 0       1  BadBunny
# 1       2  Amorfoda
# 2       3      Dura

# %%
# creating tags table and uploading data by using SQLalchemy

dtypesql = {'tag_id':sqlalchemy.types.INT, 
          'tag':sqlalchemy.types.TEXT 
}

tags.to_sql(name='tags', schema = 'test', con=engine, if_exists='fail', index=False, dtype=dtypesql)

# %%
# Setting required constraints for the table(PK, FK, and any other constraints)

conn.rollback()
cur.execute("""ALTER TABLE test.tags
                ADD CONSTRAINT tags_PK
                PRIMARY KEY (tag_id)
                ;""")
conn.commit()

cur.execute("""ALTER TABLE test.tags ALTER column tag_id SET NOT NULL;""")
conn.commit()

# %%
conn.rollback()
query = """SELECT * FROM test.tags limit 100;"""
cur.execute(query)
row = cur.fetchall()
print(row)
# Out:
# [(1, 'BadBunny'), (2, 'Amorfoda'), (3, 'Dura'), (4, 'DaddyYankee'), (5, 'Ozuna'), (6, 'RomeoSantos'), (7, 'ElFarsanteRemix'), (8, 'Drake'), (9, 'GodsPlan'), (10, 'LuisFonsi'), (11, 'DemiLovato'), (12, 'chameLaCulpa'), (13, 'Sobredosis'), (14, 'Maluma'), (15, 'Corazn'), (16, 'NegodoBorel'), (17, 'EdSheeran'), (18, 'Perfect'), (19, 'ShapeofYou'), (20, 'CamilaCabello'), (21, 'Havana'), (22, 'YoungThug'), (23, 'Wisin'), (24, 'Yandel'), (25, 'TodoComienzaenlaDisco'), (26, 'Piso'), (27, 'DjalaQueVuelva'), (28, 'ManuelTurizo'), (29, 'Despacito'), (30, 'SgueloBailando'), (31, 'Reik'), (32, 'MeNiego'), (33, 'BellaWolfine'), (34, 'TeBote'), (35, 'TeBoteRemix'), (36, 'FlowLaMovie'), (37, 'NioGarcia'), (38, 'Casper'), (39, 'NickyJam'), (40, 'Darell'), (41, 'Bad'), (42, 'Bunny'), (43, 'VideoOficial'), (44, 'MusicVideo'), (45, 'AmorFoda'), (46, 'NoQuieroQueNadieMeHableDeAmor'), (47, 'YaMeCanse'), (48, 'Quenadiemehabledeamor'), (49, 'SanValentin'), (50, 'Reggaeton'), (51, 'Odisea'), (52, 'OdiseaTheAlbum'), (53, 'ChildishGambino'), (54, 'Rap'), (55, 'ThisIsAmerica'), (56, 'mcDJRecordingRCARecords'), (57, 'Drakenewmusic'), (58, 'DrakeGodsPlan'), (59, 'ScaryHours'), (60, 'DrakeCharityGiveaway'), (61, 'DrakeinMiami'), (62, 'Ariana'), (63, 'Grande'), (64, 'No'), (65, 'Tears'), (66, 'Left'), (67, 'To'), (68, 'Cry'), (69, 'Universal'), (70, 'Records'), (71, 'Pop'), (72, 'BeckyG'), (73, 'NattiNatasha'), (74, 'NattiNatashaMusic'), (75, 'NattiNatashaOfficialVideo'), (76, 'NattiNatashaVideo'), (77, 'NattiNatashaVideoOficial'), (78, 'NattiNatashaNuevoVideo'), (79, 'NattiNatashaNewVideo'), (80, 'SinPijamaOfficialVideo'), (81, 'OfficialVideo'), (82, 'SinPijamaOfficialRemixVideo'), (83, 'SinPijamaSingle'), (84, 'Single'), (85, 'NattiNatashaNewSingle'), (86, 'NattiNatashaSingle'), (87, 'NattiNatashaSong'), (88, 'SinPijamanewsong'), (89, 'SinPijamanuevacancin'), (90, 'NattiNatashanuevacancion'), (91, 'Natti'), (92, 'Natasha'), (93, 'en'), (94, 'Rewind'), (95, 'youtuberewind'), (96, 'YouTubeRewind'), (97, 'DanandPhil'), (98, 'GraceHelbig'), (99, 'HolaSoyGerman'), (100, 'LillySingh')]

# %%
# Data samples for videos table

print(videos.columns)
videos.head(3)
# Out:
# Index(['video_id', 'title', 'channel_id', 'category_id', 'publish_time',
#        'views', 'likes', 'dislikes', 'comment_count', 'thumbnail_link',
#        'comments_disabled', 'ratings_disabled', 'video_error_or_removed',
#        'description'],
#       dtype='object')
#       video_id                                              title  channel_id  \
# 0  _I_D_8Z4sJE  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...           1
# 1  9jI-z9QN6g8  Te Bote Remix - Casper, Nio GarcÃ­a, Darell, N...           2
# 2  kLpH1nSLJSs               Bad Bunny - Amorfoda | Video Oficial           3
#
#    category_id              publish_time      views    likes  dislikes  \
# 0           10  2018-03-02T05:00:19.000Z  424538912  2818771    149275
# 1           10  2018-04-11T22:00:00.000Z  337621571  2581961    166549
# 2           10  2018-02-15T00:00:03.000Z  328860380  3823879    215530
#
#    comment_count                                  thumbnail_link  \
# 0          99380  https://i.ytimg.com/vi/_I_D_8Z4sJE/default.jpg
# 1         113564  https://i.ytimg.com/vi/9jI-z9QN6g8/default.jpg
# 2         225216  https://i.ytimg.com/vi/kLpH1nSLJSs/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
#
#                                          description
# 0  Disponible en tu plataforma preferida:\nhttps:...
# 1  Flow La Movie Presenta - Te BotÃ© Remix - Casp...
# 2  Bad Bunny - Amorfoda | Video Oficial\n\n-Click...

# %%
# creating videos table and uploading data by using SQLalchemy

dtypesql = {'video_id':sqlalchemy.types.TEXT, 
          'title':sqlalchemy.types.TEXT, 
          'channel_id':sqlalchemy.types.INT, 
          'category_id':sqlalchemy.types.INT, 
          'publish_time':sqlalchemy.types.TIMESTAMP, 
          'views':sqlalchemy.types.INT,
          'likes':sqlalchemy.types.INT, 
          'dislikes':sqlalchemy.types.INT, 
          'comment_count':sqlalchemy.types.INT,
          'thumbnail_link':sqlalchemy.types.TEXT, 
          'comments_disabled':sqlalchemy.types.BOOLEAN, 
          'ratings_disabled':sqlalchemy.types.BOOLEAN, 
          'video_error_or_removed':sqlalchemy.types.BOOLEAN, 
          'description':sqlalchemy.types.TEXT, 
}

videos.to_sql(name='videos', schema = 'test', con=engine, if_exists='fail', index=False, dtype=dtypesql)

# %%
# Setting required constraints for the table(PK, FK, and any other constraints)

conn.rollback()
cur.execute("""ALTER TABLE test.videos
                ADD CONSTRAINT videos_PK
                PRIMARY KEY (video_id)
                ;""")
conn.commit()

cur.execute("""ALTER TABLE test
ny - Amorfoda | Video Oficial\\n\\n-Click para suscribirte: http://bit.ly/badbunnypr\\n\\nFollow Me / Sigueme en: \\n\\nInstagram: https://www.instagram.com/badbunnypr/\\nSpotify: http://spoti.fi/2xQk6CX\\nFacebook: https://www.facebook.com/BadBunyPR\\nTwitter: https://twitter.com/badbunnypr\\nApple Music: http://apple.co/2f52tr9\\n\\nPara contrataciones:  +1 787-566-8600 | BadBunnyInfo@Gmail.com\\n\\nÂ© 2018 Hear This Music under exclusive license to Rimas Entertainment'), ('wfWkmURBNv8', 'Ozuna x Romeo Santos - El Farsante Remix', 4, 10, datetime.datetime(2018, 1, 30, 15, 0, 5), 288811992, 1618180, 151147, 67506, 'https://i.ytimg.com/vi/wfWkmURBNv8/default.jpg', False, False, False, 'DESCARGA Odisea Aqui: http://apple.co/2vX00sT\\n\\nDescarga Odisea The Game:\\nApp Store: http://apple.co/2hSmZiO\\nAndroid: http://bit.ly/2uwwJFb\\n\\nFollow Me / Sigueme en: \\n\\nINSTAGRAM: https://www.instagram.com/ozunapr/\\nFACEBOOK: https://www.facebook.com/ozunapr\\nTWITTER: https://twitter.com/ozunapr\\nSPOTIFY: http://spoti.fi/2tzO4Zv\\nAPPLE MUSIC: http://apple.co/2uu3phf\\n\\nManager: \\nVicente Saavedra: Saavedrabooking@gmail.com | +1-787-444-5678'), ('VYOjWnS4cMY', 'Childish Gambino - This Is America (Official Video)', 5, 10, datetime.datetime(2018, 5, 6, 4, 0, 7), 259721696, 5444541, 379862, 553371, 'https://i.ytimg.com/vi/VYOjWnS4cMY/default.jpg', False, False, False, 'â\x80\x9cThis is Americaâ\x80\x9d by Childish Gambino http://smarturl.it/TcIgADirector: Hiro MuraiProducer: Jason Cole of Doomsday with Ibra Ake and Fam Rothstein of Wolf + Rothsteintour tickets and merchandise ava ...

# %%
# Data samples for videos_tags table

print(video_tags.columns)
video_tags.head(3)
# Out:
# Index(['id', 'video_id', 'tag_id'], dtype='object')
#    id     video_id  tag_id
# 0   0  _I_D_8Z4sJE       1
# 1   1  _I_D_8Z4sJE       2
# 2   2  _I_D_8Z4sJE       3

# %%
# creating videos_tags table and uploading data by using SQLalchemy

dtypesql = {'id':sqlalchemy.types.INT, 
          'video_id':sqlalchemy.types.TEXT,
          'tag_id':sqlalchemy.types.INT,
}

video_tags.to_sql(name='videos_tags', schema = 'test', con=engine, if_exists='fail', index=False, dtype=dtypesql)

# %%
# Setting required constraints for the table(PK, FK, and any other constraints)

conn.rollback()
cur.execute("""ALTER TABLE test.videos_tags
                ADD CONSTRAINT videos_tags_PK
                PRIMARY KEY (id)
                ;""")
conn.commit()

cur.execute("""ALTER TABLE test.videos_tags ALTER column id SET NOT NULL;""")
conn.commit()

cur.execute("""ALTER TABLE test.videos_tags
                ADD CONSTRAINT videos_FK
                FOREIGN KEY (video_id)
                REFERENCES test.videos (video_id)
                MATCH FULL
                ;""")
conn.commit()

cur.execute("""ALTER TABLE test.videos_tags
                ADD CONSTRAINT tags_FK
                FOREIGN KEY (tag_id)
                REFERENCES test.tags (tag_id)
                MATCH FULL
                ;""")
conn.commit()

# %%
conn.rollback()
query = """SELECT * FROM test.videos_tags limit 100;"""
cur.execute(query)
row = cur.fetchall()
print(row)
# Out:
# [
oY1aTE'), (55, 'SM1w9PEQOE8'), (56, 'VRJmcxCrAOA'), (57, 'pnMQLrS5sTE'), (58, 'X8sSXU-J8fI'), (59, 'fGqdIPer-ms'), (60, 'oWjxSkJpxFU'), (61, 'dUaCEs3HfdI'), (62, 'pVxOVlm_lE8'), (63, 'dZ0fwJojhrs'), (64, 'zkG4Xpz6t68'), (65, 'g4Hbz2jLxvQ'), (66, 'wfWIs2gFTAM'), (67, 'gu9_m0vm7fM'), (68, '9v_rtaye2yY'), (69, 'wbSwFU6tY1c'), (70, 'V5cOvyDpWfM'), (71, 'J-dv_DcDD_A'), (72, 'Wpm07-BGJnE'), (73, '4dCJgNzgs3c'), (74, 'sGIm0-dQd8M'), (75, 'j-I0Uxbh1uY'), (76, '64UX1npgRkI'), (77, '7vracgLyJwI'), (78, 'BQ31l1gPGKM'), (79, 'IZODr96ZRCc'), (80, 'naW9U8MiUY0'), (81, 'S9KxqRUcnCU'), (82, 'SAcpESN_Fk4'), (83, 'p8npDG2ulKQ'), (84, '5__KOPGuLDE'), (85, '3h4thS-Hcrk'), (86, '3BXDsVD6O10'), (87, 'lhnmVSB-Rxc'), (88, 'M4ZoCHID9GI'), (89, 'NooW_RbfdWI'), (90, 'xZNBFcwd7zc'), (91, 'fAIX12F6958'), (92, 'WS7f5xpGYn8'), (93, 'MuPL-PSMX0Q'), (94, 'RSRzIrOqaN4'), (95, 'aNwWdF8qq-M'), (96, '9jI-z9QN6g8'), (97, 'z5WrgDzNIZ0'), (98, 'Wm_vSSlVsV4'), (99, '8-mloCL49vs'), (100, 'UUkn-enk2RU')]

# %%
# creating us_videos table and uploading data by using SQLalchemy for future use
# (we didn't use this table for our analysis, therefore, this table is not included in ERD and data dictionary)

dtypesql = {'id':sqlalchemy.types.INT, 
          'video_id':sqlalchemy.types.TEXT 
}

us_videos.to_sql(name='us_videos', schema = 'test', con=engine, if_exists='fail', index=False, dtype=dtypesql)

# %%
# Setting required constraints for the table(PK, FK, and any other constraints)

conn.rollback()
cur.execute("""ALTER TABLE test.us_videos
                ADD CONSTRAINT us_videos_PK
                PRIMARY KEY (id)
                ;""")
conn.commit()

cur.execute("""ALTER TABLE test.us_videos ALTER column id SET NOT NULL;""")
conn.commit()

cur.execute("""ALTER TABLE test.us_videos
                ADD CONSTRAINT us_videos_FK
                FOREIGN KEY (video_id)
                REFERENCES test.videos (video_id)
                MATCH FULL
                ;""")
conn.commit()

# %%
conn.rollback()
query = """SELECT * FROM test.us_videos limit 100;"""
cur.execute(query)
row = cur.fetchall()
print(row)
# Out:
# [(1, 'VYOjWnS4cMY'), (2, 'FlsCjmMhFmw'), (3, 'ffxKSjUwKdU'), (4, 'zEf423kYfqk'), (5, '7C2z4GqqS5E'), (6, 'M4ZoCHID9GI'), (7, 'TyHvyGVs42U'), (8, 'xTlNMmZKwpA'), (9, '6ZfuNTqbHE8'), (10, '-BQJo3vK8O8'), (11, 'tCXGJQYZ9JA'), (12, 'DkeiKbqa02g'), (13, 'i0p1bmr0EmE'), (14, 'aJOTlE1K90k'), (15, 'U9BwWKXjVaI'), (16, 'vjI4Alon-3Q'), (17, 'u9Mv98Gr5pY'), (18, 'LsoLEjrDogU'), (19, 'BhIEIO0vaBE'), (20, 'iWZmdoY1aTE'), (21, 'ulNswX3If6U'), (22, '_9YMpuLDnwo'), (23, 'QwievZ1Tx-8'), (24, 'rRr1q
conn.rollback()
cur.execute("""ALTER TABLE test.gb_videos
                ADD CONSTRAINT gb_videos_PK
                PRIMARY KEY (id)
                ;""")
conn.commit()

cur.execute("""ALTER TABLE test.gb_videos ALTER column id SET NOT NULL;""")
conn.commit()

cur.execute("""ALTER TABLE test.gb_videos
                ADD CONSTRAINT gb_videos_FK
                FOREIGN KEY (video_id)
                REFERENCES test.videos (video_id)
                MATCH FULL
                ;""")
conn.commit()

# %%
conn.rollback()
query = """SELECT * FROM test.gb_videos limit 100;"""
cur.execute(query)
row = cur.fetchall()
print(row)
# Out:
# [(1, '_I_D_8Z4sJE'), (2, '9jI-z9QN6g8'), (3, 'kLpH1nSLJSs'), (4, 'wfWkmURBNv8'), (5, 'VYOjWnS4cMY'), (6, 'xpVfcZ0ZcFM'), (7, 'ffxKSjUwKdU'), (8, 'zEf423kYfqk'), (9, 'FlsCjmMhFmw'), (10, 'sGIm0-dQd8M'), (11, 'TyHvyGVs42U'), (12, '2Vv-BfVoq4g'), (13, 'M4ZoCHID9GI'), (14, 'Ck4xHocysLw'), (15, '7C2z4GqqS5E'), (16, 'tCXGJQYZ9JA'), (17, 'U9BwWKXjVaI'), (18, 'au2n7VVGv_c'), (19, '6ZfuNTqbHE8'), (20, 'fGqdIPer-ms'), (21, 'DkeiKbqa02g'), (22, 'i0p1bmr0EmE'), (23, 'JNkTNAknE4I'), (24, 'xTlNMmZKwpA'), (25, 'WtE011iVx1Q'), (26, 'sD9_l3oDOag'), (27, 'VTzD0jNdrmo'), (28, 'LsoLEjrDogU'), (29, 'gu9_m0vm7fM'), (30, 'dfnCAmr569k'), (31, 'iWZmdoY1aTE'), (32, 'aJOTlE1K90k'), (33, '36tggrpRoTI'), (34, '817P8W8-mGE'), (35, 'z5WrgDzNIZ0'), (36, 'zkG4Xpz6t68'), (37, 'Mgfe5tIwOj0'), (38, 'vjI4Alon-3Q'), (39, 'BQ31l1gPGKM'), (40, 'pgN-vvVVxMA'), (41, 'NV-3s2wwC8c'), (42, 'UceaB4D0jpo'), (43, 'l_lblj8Cq0o'), (44, 'liczsmUSMA4'), (45, 'LPTlvQ1Zet0'), (46, 'JQbjS0_ZfJ0'), (47, 'Iwz4P8HfGVM'), (48, 'MGYJuETPQEg'), (49, 'wfWIs2gFTAM'), (50, 'DqSBQqj94JU'), (51, 'BhIEIO0vaBE'), (52, 'X8sSXU-J8fI'), (53, 'J-dv_DcDD_A'), (54, 'FVRPzwb1Vi4'), (55, '0XElmYomloA'), (56, 'eACohWVwTOc'), (57, 'QwievZ1Tx-8'), (58, 'rRzxEiBLQCA'), (59, 'u9Mv98Gr5pY'), (60, '8q1NFlE17qs'), (61, 'qtTM2YV3bI8'), (62, 'kTlv5_Bs8aw'), (63, 'y0PMqR7IbAQ'), (64, 'Wpm07-BGJnE'), (65, 'LJjsm6CVsG8'), (66, 'oWw1BcFhk-k'), (67, '9TRjE7i0ERY'), (68, '1Aoc-cd9eYs'), (69, 'tsp7IOr7Q9A'), (70, 'U4fErC9skHE'), (71, '6YNZlXfW6Ho'), (72, 'jzD_yyEcp0M'), (73, 'VwAnsAUYnw4'), (74, '95Rzsn-zjr0'), (75, '4uTNVumfm84'), (76, 'QwZT7T-TXT0'), (77, '31OMf1H5Rk0'), (78, 'wzKL-bQKcgA'), (79, 'J6-8DQALGt4'), (80, 'Ph54wQG8ynk'), (81, 'ToY6sjSV8h8'), (82, 'vUTI4bPdlgE'), (83, 'YBpdL9hSac4'), (84, 'vn9mMeWcgoM'), (85, 'n1WpP7iowLc'), (86, 'pjTj-_55WZ8'), (87, 'WS7f5xpGYn8'), (88, '4GFAZBKZVJY'), (89, 'VY1eFxgRR-k'), (90, 'xVhnfTwh1OA'), (91, 'pVxOVlm_lE8'), (92, 'op4B9sNGi0k'), (93, 'kton-qrKNLc'), (94, 'khPLWaBioOs'), (95, '9t9u_yPEidY'), (96, 'tcaw6lzYt1Q'), (97, 'sS0LCjOiIhc'), (98, 'p03TIGqEc8o'), (99, 'aEM2kOrrNJI'), (100, 'CX11yw6YL1w')]

# %%
# Information about created tables 1

conn.rollback()
query = """SELECT A.*, B.*
            FROM INFORMATION_SCHEMA.TABLE_CONSTRAINTS       A
                 , INFORMATION_SCHEMA.CONSTRAINT_COLUMN_USAGE B
            WHERE A.TABLE_CATALOG   = 'postgres'
            AND A.table_schema = 'test'
               --AND A.TABLE_NAME      = 'categories'
               --AND A.CONSTRAINT_TYPE = 'PRIMARY KEY'
               AND A.TABLE_CATALOG   = B.TABLE_CATALOG
               AND A.TABLE_SCHEMA    = B.TABLE_SCHEMA
               AND A.TABLE_NAME      = B.TABLE_NAME
               --AND A.CONSTRAINT_NAME = B.CONSTRAINT_NAME
;"""
cur.execute(query)
row = cur.fetchall()
print(row)
# Out:
# [('postgres', 'test', 'categories_pk', 'postgres', 'test', 'categories', 'PRIMARY KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'categories', 'category_id', 'postgres', 'test', 'categories_pk'), ('postgres', 'test', 'categories_pk', 'postgres', 'test', 'categories', 'PRIMARY KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'categories', 'category_id', 'postgres', 'test', 'videos_categories_fk'), ('postgres', 'test', 'channels_pk', 'postgres', 'test', 'channels', 'PRIMARY KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'channels', 'channel_id', 'postgres', 'test', 'channels_pk'), ('postgres', 'test', 'channels_pk', 'postgres', 'test', 'channels', 'PRIMARY KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'channels', 'channel_id', 'postgres', 'test', 'videos_channels_fk'), ('postgres', 'test', 'tags_pk', 'postgres', 'test', 'tags', 'PRIMARY KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'tags', 'tag_id', 'postgres', 'test', 'tags_pk'), ('postgres', 'test', 'tags_pk', 'postgres', 'test', 'tags', 'PRIMARY KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'tags', 'tag_id', 'postgres', 'test', 'tags_fk'), ('postgres', 'test', 'videos_pk', 'postgres', 'test', 'videos', 'PRIMARY KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'videos', 'video_id', 'postgres', 'test', 'videos_pk'), ('postgres', 'test', 'videos_pk', 'postgres', 'test', 'videos', 'PRIMARY KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'videos', 'video_id', 'postgres', 'test', 'videos_fk'), ('postgres', 'test', 'videos_channels_fk', 'postgres', 'test', 'videos', 'FOREIGN KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'videos', 'video_id', 'postgres', 'test', 'videos_pk'), ('postgres', 'test', 'videos_channels_fk', 'postgres', 'test', 'videos', 'FOREIGN KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'videos', 'video_id', 'postgres', 'test', 'videos_fk'), ('postgres', 'test', 'videos_categories_fk', 'postgres', 'test', 'videos', 'FOREIGN KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'videos', 'video_id', 'postgres', 'test', 'videos_pk'), ('postgres', 'test', 'videos_categories_fk', 'postgres', 'test', 'videos', 'FOREIGN KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'videos', 'video_id', 'postgres', 'test', 'videos_fk'), ('postgres', 'test', 'videos_tags_pk', 'postgres', 'test', 'videos_tags', 'PRIMARY KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'videos_tags', 'id', 'postgres', 'test', 'videos_tags_pk'), ('postgres', 'test', 'videos_fk', 'postgres', 'test', 'videos_tags', 'FOREIGN KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'videos_tags', 'id', 'postgres', 'test', 'videos_tags_pk'), ('postgres', 'test', 'tags_fk', 'postgres', 'test', 'videos_tags', 'FOREIGN KEY', 'NO', 'NO', 'YES', 'postgres', 'test', 'videos_tags', 'id', 'postgres', 'test', 'videos_tags_pk'), ('postgres', 'test', '57486_57522_1_not_null', 'postgres', 'test', 'tags', 'CHECK', 'NO', 'NO', 'YES', 'postgres', 'test', 'tags', 'tag_id', 'postgres', 'test', 'tags_pk'), ('postgres', 'test', '57486_57522_1_not_null', 'postgres', 'test', 'tags', 'CHECK', 'NO', 'NO', 'YES', 'postgres', 'test', 'tags', 'tag_id', 'postgres', 'test', 'tags_fk'), ('postgres', 'test', '57486_57515_1_not_null', 'postgres', 'test', 'channels', 'CHECK', 'NO', 'NO', 'YES', 'postgres', 'test', 'channels', 'channel_id', 'postgres', 'test', 'channels_pk'), ('postgres', 'test', '57486_57515_1_not_null', 'postgres', 'test', 'channels', 'CHECK', 'NO', 'NO', 'YES', 'postgres', 'test', 'channels', 'channel_id', 'postgres', 'test', 'videos_channels_fk'), ('postgres', 'test', '57486_57509_1_not_null', 'postgres', 'test', 'categories', 'CHECK', 'NO', 'NO', 'YES', 'postgres', 'test', 'categories', 'category_id', 'postgres', 'test', 'categories_pk'), ('postgres', 'test', '57486_57509_1_not_null', 'postgres', 'test', 'categories', 'CHECK', 'NO', 'NO', 'YES', 'postgres', 'test', 'categories', 'category_id', 'postgres', 'test', 'videos_categories_fk'), ('postgres', 'test', '57486_57537_1_not_null', 'postgres', 'test', 'videos', 'CHECK', 'NO', 'NO', 'YES', 'postgres', 'test', 'videos', 'v ...

# %%
# Information about created tables 2

conn.rollback()
query = """select *
            from information_schema.columns
            where table_schema = 'test';"""
cur.execute(query)
row = cur.fetchall()
print(row)
# Out:
# [('postgres', 'test', 'videos', 'dislikes', 8, None, 'YES', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'postgres', 'pg_catalog', 'int4', None, None, None, None, '8', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'), ('postgres', 'test', 'videos', 'views', 6, None, 'YES', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'postgres', 'pg_catalog', 'int4', None, None, None, None, '6', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'), ('postgres', 'test', 'categories', 'category_name', 2, None, 'YES', 'text', None, 1073741824, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'postgres', 'pg_catalog', 'text', None, None, None, None, '2', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'), ('postgres', 'test', 'videos', 'video_id', 1, None, 'NO', 'text', None, 1073741824, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'postgres', 'pg_catalog', 'text', None, None, None, None, '1', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'), ('postgres', 'test', 'videos_tags', 'video_id', 2, None, 'YES', 'text', None, 1073741824, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'postgres', 'pg_catalog', 'text', None, None, None, None, '2', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'), ('postgres', 'test', 'videos', 'category_id', 4, None, 'YES', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'postgres', 'pg_catalog', 'int4', None, None, None, None, '4', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'), ('postgres', 'test', 'tags', 'tag_id', 1, None, 'NO', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'postgres', 'pg_catalog', 'int4', None, None, None, None, '1', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'), ('postgres', 'test', 'videos', 'likes', 7, None, 'YES', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'postgres', 'pg_catalog', 'int4', None, None, None, None, '7', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'), ('postgres', 'test', 'videos', 'comment_count', 9, None, 'YES', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'postgres', 'pg_catalog', 'int4', None, None, None, None, '9', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'), ('postgres', 'test', 'channels', 'channel_id', 1, None, 'NO', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'postgres', 'pg_catalog', 'int4', None, None, None, None, '1', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'), ('postgres', 'test', 'videos', 'description', 14, None, 'YES', 'text', None, 1073741824, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'postgres', 'pg_catalog', 'text', None, None, None, None, '14', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'), ('postgres', 'test', 'videos', 'channel_id', 3, None, 'YES', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'postgres', 'pg_catalog', 'int4', None, None, None, None, '3', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'), ('postgres', 'test', 'channels', 'channel_title', 2, None, 'YES', 'text', None, 1073741824, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'postgres', 'pg_catalog', 'text', None, None, None, None, '2', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'), ('postgres', 'test', 'videos_tags', 'tag_id ...

# %% [markdown]
# # Test codes for using Youtube API

# %%
import requests
import json

key = 'Youtube API Key'
maxResults = '100' 
order = 'viewCount' 
type = 'video'

uri = f'https://www.googleapis.com/youtube/v3/search?part=snippet&key={key}&maxResults={maxResults}&order={order}&type={type}'

data = requests.get(uri).json()

data['items']
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': 'cIVcGrvO5mzNLN6hAFQvkJY27C8',
#   'id': {'kind': 'youtube#video', 'videoId': 'zNESDscyCmk'},
#   'snippet': {'publishedAt': '2021-09-02T06:40:07Z',
#    'channelId': 'UCuzqko_GKcj9922M1gUo__w',
#    'title': '【看盤不中斷】EBC東森財經股市24小時直播｜Taiwan EBC Financial News 24h live｜台湾 EBC 金融ニュース24 時間オンライン放送｜대만 뉴스 생방송',
#    'description': '【東森財經新聞YouTube】 https://www.youtube.com/user/57ETFN\u200b 【這不是新聞股市 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/
...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fkB9iOGcEP0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/fkB9iOGcEP0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/fkB9iOGcEP0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'PANJI PETUALANG',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T11:55:12Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'FmxE49EeTWuv-rwX2hWwJ97-JfQ',
#   'id': {'kind': 'youtube#video', 'videoId': '8qrAI4qraHw'},
#   'snippet': {'publishedAt': '2022-02-08T11:00:04Z',
#    'channelId': 'UCvxi7_X1VSaMr_osIamYNaw',
#    'title': 'Mallikarjun Khadge ने ऐसा क्या किया कि PM Modi ने कहा आप भी Adhir Ranjan वाली गलती न करें',
#    'description': 'Mallikarjun Khadge ने ऐसा क्या किया कि PM Modi ने कहा आप भी Adhir Ranjan वाली गलती न करें.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8qrAI4qraHw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/8qrAI4qraHw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/8qrAI4qraHw/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'NMF News',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T11:00:04Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'YyNcdX8hLW44QNVJvnxGeELMauw',
#   'id': {'kind': 'youtube#video', 'videoId': 'PUIDCQ6cOXk'},
#   'snippet': {'publishedAt': '2022-02-07T22:02:14Z',
#    'channelId': 'UC5TccbGxEeVMx9gL6wp9fOg',
#    'title': 'Evleniyoruz... - Yasak Elma 130. Bölüm',
#    'description': 'Kumru hamile!!! Yasak Elma Resmi YouTube Kanalı: https://goo.gl/7AqfHc Yasak Elma ailesine katılmak için linke tıklayın; ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PUIDCQ6cOXk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/PUIDCQ6cOXk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/PUIDCQ6cOXk/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Yasak Elma',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-07T22:02:14Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'o9Ndwhj7f-rM2sipGf6LQAMZu0o',
#   'id': {'kind': 'youtube#video', 'videoId': 'IHcR7BW8NeA'},
#   'snippet': {'publishedAt': '2020-07-19T08:00:02Z',
#    'channelId': 'UCWskYkV4c4S9D__rsfOl2JA',
#    'title': '단기 조정기에 사서 내년 폭등장 누려라/ #김영익 서강대 겸임교수 인터뷰',
#    'description': '7월5,6일 주코노미TV에 나간 인터뷰 영상의 풀버전입니다. ▷한국경제 네이버 TV 바로가기 https://tv.naver.com/nowhankyung #한국 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IHcR7BW8NeA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/IHcR7BW8NeA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/IHcR7BW8NeA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': '한경 글로벌마켓',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-07-19T08:00:02Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'QMyBbWkwuBelxcR1W7wewDESSpQ',
#   'id': {'kind': 'youtube#video', 'videoId': 'cWsEzcV5bXk'},
#   'snippet': {'publishedAt': '2022-02-08T09:15:01Z',
#    'channelId': 'UCtrovMbRR6h_XLMfdbhqb1A',
#    'title': 'CHANDRALEKHA Serial | Episode 2101 | 8th Feb 2022 | Shwetha | Jai Dhanush | Nagashree | Arun',
#    'description': "Watch today's episode of Chandralekha serial: SUBSCRIBE to Saregama TVshows Tamil Channel and Don't forget to switch ON ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cWsEzcV5bXk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/cWsEzcV5bXk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/cWsEzcV5bXk/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Saregama TV Shows Tamil',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T09:15:01Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '2egUzxkU4VTJXYEAbFcKfGMmnt0',
#   'id': {'kind': 'youtube#video', 'videoId': 'kJkfqZ8q2Hs'},
#   'snippet': {'publishedAt': '2022-02-08T12:00:12Z',
#    'channelId': 'UCXfb0tTEMp2wq__vQi76dMw',
#    'title': 'KESEDIHAN BILLY SYAHPUTRA SAAT DITINGGAL MEMES UNTUK BEBERAPA BULAN KE EROPA',
#    'description': 'https://youtu.be/kJkfqZ8q2Hs #billysyahputra #memesprameswari.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kJkfqZ8q2Hs/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/kJkfqZ8q2Hs/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/kJkfqZ8q2Hs/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Billy Syahputra',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T12:00:12Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'HZN9TrlUBMoxLVKXssB_RkFPdL8',
#   'id': {'kind': 'youtube#video', 'videoId': 'a75fa_Yah_Q'},
#   'snippet': {'publishedAt': '2022-02-08T00:31:22Z',
#    'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#    'title': 'Trump’s Latest Document Debacle | Zerlina.',
#    'description': 'A Washington Post report says former Pres. Trump took boxes (yes, plural) of presidential documents from the White House to ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/a75fa_Yah_Q/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/a75fa_Yah_Q/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/a75fa_Yah_Q/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'MSNBC',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T00:31:22Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Ax-10sMe4Ra1YI82eMKZKdsoQjQ',
#   'id': {'kind': 'youtube#video', 'videoId': 'zJxXT1xaOLM'},
#   'snippet': {'publishedAt': '2022-02-08T12:00:34Z',
#    'channelId': 'UCz8lelVfalizvMb2bHQjDvg',
#    'title': 'ÇIZDIGIM HERŞEY OYUNDA GERÇEK OLUYOR (DEV TUVALET) #03 - GTA 5 MODS',
#    'description': "Beğenmeyi unutmayın Zil'e tıklayıp bildirmleri açabilirsiniz tskler. CANLI YAYINLARIMA BEKLERİM Facebook ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zJxXT1xaOLM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/zJxXT1xaOLM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/zJxXT1xaOLM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'TÜRKPRO',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T12:00:34Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '73RILQ91L9sOK3Pm3vQwJE1pNFA',
#   'id': {'kind': 'youtube#video', 'videoId': 'rWCECHmxr6E'},
#   'snippet': {'publishedAt': '2022-02-08T17:00:27Z',
#    'channelId': 'UCSf0s2ogUVYpJPuzW1zpAOg',
#    'title': 'LANKYBOX Reacts To TOP 5 CRAZIEST MEMES!? (FIVE NIGHTS AT FREDDY&#39;S vs POPPY PLAYTIME!)',
#    'description': "LANKYBOX Reacts To TOP 5 CRAZIEST MEMES!? (FIVE NIGHTS AT FREDDY'S vs POPPY PLAYTIME!) LANKYBOX MERCH ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rWCECHmxr6E/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/rWCECHmxr6E/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/rWCECHmxr6E/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'LankyBox',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T17:00:27Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '1GqNwXKgTWbS4GjJ-6vQpqBzxyw',
#   'id': {'kind': 'youtube#video', 'videoId': 'sjdBtcloPgQ'},
#   'snippet': {'publishedAt': '2022-02-08T12:30:30Z',
#    'channelId': 'UCGvU5WR10YVbaDo7PTIfC9A',
#    'title': 'Mimi e Julinha em uma História Engraçada de Uma Nova IRMÃ BEBÊ',
#    'description': 'Mimi e Julinha em uma História Engraçada de Uma Nova IRMÃ BEBÊ. Julinha quer brincar mas seu irmão só quer brincar com a ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sjdBtcloPgQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/sjdBtcloPgQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/sjdBtcloPgQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Mimi Julinha',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T12:30:30Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'adq47-pWmSoMc-2-dfPl8EIHfkM',
#   'id': {'kind': 'youtube#video', 'videoId': 'jZJZMdsGqis'},
#   'snippet': {'publishedAt': '2022-02-08T00:33:06Z',
#    'channelId': 'UCZdQjaSoLjIzFnWsDQOv4ww',
#    'title': 'Swapping out our 48ft home, for another.. TRIMARAN update!',
#    'description': '336 COME SAIL WITH US!! For your chances to win a week of sailing with us in the Bahamas this Spring, sign up to our Patreon ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jZJZMdsGqis/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/jZJZMdsGqis/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/jZJZMdsGqis/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Sailing La Vagabonde',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T00:33:06Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '-ND6aAyo8j6c0ysqk8DMH6eauDE',
#   'id': {'kind': 'youtube#video', 'videoId': 'AzTokNeWs5k'},
#   'snippet': {'publishedAt': '2022-02-08T01:00:02Z',
#    'channelId': 'UC7723FqVehXq2zeRb3tP0hQ',
#    'title': 'Tin quốc tế 8/2 | Ông Putin có thể mất ghế Tổng thống nếu ra lệnh tấn công Ukraine? | FBNC',
#    'description': 'Tin quốc tế 8/2 | Ông Putin có thể mất ghế Tổng thống nếu ra lệnh tấn công Ukraine? | FBNC TRUYỀN NHÂN LÃNH ĐẠO ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AzTokNeWs5k/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/AzTokNeWs5k/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/AzTokNeWs5k/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'FBNC Vietnam',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T01:00:02Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'G42gpJd2ObQvdPpQBwlfu80FZPg',
#   'id': {'kind': 'youtube#video', 'videoId': '_zhDww9VUOc'},
#   'snippet': {'publishedAt': '2022-02-08T16:30:07Z',
#    'channelId': 'UCXWNExSw2KO7e0xCziQly0A',
#    'title': 'Брошенный Toyota Prado - Финал истории, который мы не ждали…',
#    'description': 'Господа! Жизнь порой подкидывает нам занятные истории, в некоторых, финал предсказуем, в некоторых могут помочь ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_zhDww9VUOc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/_zhDww9VUOc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/_zhDww9VUOc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Клубный сервис',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T16:30:07Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'MErC7GnhzI1TXE5LL9GBvjHduWI',
#   'id': {'kind': 'youtube#video', 'videoId': 'xfB5P0ILfQ4'},
#   'snippet': {'publishedAt': '2018-05-17T10:00:34Z',
#    'channelId': 'UCg_vCUNRzKCOLxrrZqrQ0Yw',
#    'title': 'ASUS Zenfone 5 : 5 Hal Penting 🔥',
#    'description': 'Generasi Zenfone terbaru dari ASUS! Update: Mulai dijual 31 Mei 2018 Harga Zenfone 5: Rp 3.999.000,- (Flash Sale), Rp ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xfB5P0ILfQ4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/xfB5P0ILfQ4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/xfB5P0ILfQ4/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Bestindotech',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2018-05-17T10:00:34Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'bMY81XOO_g1c-VIDtqtKrxAmFxw',
#   'id': {'kind': 'youtube#video', 'videoId': 'Y2JST4sUmTA'},
#   'snippet': {'publishedAt': '2019-03-01T10:00:04Z',
#    'channelId': 'UCg_vCUNRzKCOLxrrZqrQ0Yw',
#    'title': 'DIBAWAH 350K!! Gadget of The Month Episode.2 2019',
#    'description': 'Link Pembelian: 1. Puridea i6 Speaker: https://invol.co/cli5em 2. Shaver mini Xiaomi: https://invol.co/cli5er Shaver versi murah: ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Y2JST4sUmTA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Y2JST4sUmTA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Y2JST4sUmTA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Bestindotech',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-03-01T10:00:04Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'uqIAR3_KJz9Ushorzxl-umaCGro',
#   'id': {'kind': 'youtube#video', 'videoId': 'LlJhh0HyeFU'},
#   'snippet': {'publishedAt': '2022-02-08T15:56:34Z',
#    'channelId': 'UC0ctt9lkdKnza7QQfI7i9YA',
#    'title': 'Коммент.Матч | Спартак - Урал',
#    'description': 'Всем салют! Сегодня показываем игру московского Спартака против Урала. В студии работают Костя Генич и Александр ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LlJhh0HyeFU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/LlJhh0HyeFU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/LlJhh0HyeFU/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Коммент.Шоу',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T15:56:34Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Iu3cbsTEXWd_dDR7dbJcb2ymXk0',
#   'id': {'kind': 'youtube#video', 'videoId': '4jVa8TZvXuI'},
#   'snippet': {'publishedAt': '2022-02-07T21:17:01Z',
#    'channelId': 'UC-9ki_1Lsef3ZMLiJAHD7eQ',
#    'title': 'Üç Kuruş 13. Bölüm - Hadi Atla Bir Tur Gezelim...',
#    'description': "Bu dizi ve çok daha fazlası puhutv'de ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4jVa8TZvXuI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/4jVa8TZvXuI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/4jVa8TZvXuI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Üç Kuruş',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-07T21:17:01Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'qeJY5Sy_JIJq9mk5XHxAZJcoQrU',
#   'id': {'kind': 'youtube#video', 'videoId': 'FNiN163i4TQ'},
#   'snippet': {'publishedAt': '2022-02-08T16:16:57Z',
#    'channelId': 'UCWuKx41wAvbz_NNu1oD6bsQ',
#    'title': 'EPIC GAMES dodało NOWY ITEM do FORTNITE',
#    'description': 'Epic Games dodało nowy sekretny item do fortnite rozdział 3 (fortnite chapter 3) w nowej aktualizacji (nowy update fortnite) i ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FNiN163i4TQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/FNiN163i4TQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/FNiN163i4TQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Jacob',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T16:16:57Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Shf7RyhJqICO-QVo5I-v7HIdjhk',
#   'id': {'kind': 'youtube#video', 'videoId': '9wv2Ha5F7v0'},
#   'snippet': {'publishedAt': '2022-02-08T13:21:29Z',
#    'channelId': 'UCuzS3rPQAYqHcLWqOFuY0pw',
#    'title': 'Rashtra Ki Baat: Akhilesh Vs Yogi, किसका Ghoshnapatra जिताएगा UP Election | Mamata | Manak Gupta',
#    'description': 'Rashtra Ki Baat: BJP Vs SP... किसका घोषणा पत्र जिताएगा चुनाव ? देखिये Manak Gupta के साथ News24 motto of ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9wv2Ha5F7v0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/9wv2Ha5F7v0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/9wv2Ha5F7v0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'News24',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T13:21:29Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '9EA3f_YrOWLVECUrvVKlz5Z6L2w',
#   'id': {'kind': 'youtube#video', 'videoId': '_b6ZN_grTj4'},
#   'snippet': {'publishedAt': '2022-02-08T16:00:13Z',
#    'channelId': 'UCeCfdHkqTcC7atfxNE7X38Q',
#    'title': 'TRUCOS GENIALES PARA CUALQUIER OCASIÓN || Trucos geniales e ideas inteligentes de 123 GO! GOLD',
#    'description': 'Desde faltar a la escuela hasta trucos de ropa y consejos de jardinería! ¡Este nuevo video está lleno de trucos útiles! ¡Disfruta y ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_b6ZN_grTj4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/_b6ZN_grTj4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/_b6ZN_grTj4/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': '123 GO! GOLD Spanish',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T16:00:13Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '0I9VPScIortolY3uhJmMdqaiUCc',
#   'id': {'kind': 'youtube#video', 'videoId': 'lCOr6jkBcTA'},
#   'snippet': {'publishedAt': '2022-02-08T17:00:36Z',
#    'channelId': 'UC14OarNMc15ZxzlDziVShXg',
#    'title': 'GTA V PRAWDZIWE ŻYCIE #13 ZNOWU NIE ZDAŁEM!... 🤬 [S3]',
#    'description': 'KUP POLAR ZE SPECJALNYM AUTOGRAFEM! : https://teamkaluch.pl ⭐OFICJALNY DISCORD TK ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lCOr6jkBcTA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/lCOr6jkBcTA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/lCOr6jkBcTA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Kaluch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T17:00:36Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'V4ics0Ps3f38cPSNC_ucyp25UNE',
#   'id': {'kind': 'youtube#video', 'videoId': 'nNQAf6NMtc0'},
#   'snippet': {'publishedAt': '2018-11-09T16:28:18Z',
#    'channelId': 'UCQIrvVPHrt2cN14ktGA2Snw',
#    'title': 'THE VICTIM - Film COMPLET en français',
#    'description': 'En jouant les rôles de victimes sur les reconstitutions de scènes de crime, une jeune actrice commence à se faire connaître et ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nNQAf6NMtc0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/nNQAf6NMtc0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/nNQAf6NMtc0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Cinéma Cinémas',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2018-11-09T16:28:18Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'IZmsX1vUHxn0xih-Ottq9tC4osY',
#   'id': {'kind': 'youtube#video', 'videoId': '9iLjZVOJ2KY'},
#   'snippet': {'publishedAt': '2022-02-08T04:32:49Z',
#    'channelId': 'UCX2XQHzw7HMhtHKQHlzrZiQ',
#    'title': 'সারস বউ ৮৬ | কালো নদীর জল | Saras Bou 86 | Animate ME',
#    'description': 'All the characters and events of this story are imaginary. It has no connection with any dead, living or religion. And the content of ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9iLjZVOJ2KY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/9iLjZVOJ2KY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/9iLjZVOJ2KY/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Animate ME',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T04:32:49Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'YIROX47aXO5vFIgaIM0_wUqx23s',
#   'id': {'kind': 'youtube#video', 'videoId': 'lFoian7WyHg'},
#   'snippet': {'publishedAt': '2022-02-08T09:30:12Z',
#    'channelId': 'UClAfLVQYZSLrMAQQ_SXPVZw',
#    'title': '[오연호가 묻다] 김누리 교수의 분노 &quot;미성숙 엘리트가 한국사회 지배, 독일에선 &#39;윤석열 후보&#39; 불가능&quot;',
#    'description': '덴마크 행복교육 전문가 오연호가 묻고, 독일 정치교육 전문가 김누리 교수가 답하다. 아무도 예상하지 못했던 2022년 대선의 새로운 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lFoian7WyHg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/lFoian7WyHg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/lFoian7WyHg/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'OhmynewsTV',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T09:30:12Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'UErl8SL4Dnfd4MCq4aRMCXNWeg8',
#   'id': {'kind': 'youtube#video', 'videoId': 'ncbwwdA-JUM'},
#   'snippet': {'publishedAt': '2022-02-07T21:15:03Z',
#    'channelId': 'UC5TccbGxEeVMx9gL6wp9fOg',
#    'title': 'Kumru, bebeği nereye götürdü - Yasak Elma 130. Bölüm',
#    'description': 'Kumru bebeği nereye götürdü? Yasak Elma Resmi YouTube Kanalı: https://goo.gl/7AqfHc Yasak Elma ailesine katılmak için linke ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ncbwwdA-JUM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ncbwwdA-JUM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ncbwwdA-JUM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Yasak Elma',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-07T21:15:03Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'NbS_Udknz9IdDdpciBTE113rvsc',
#   'id': {'kind': 'youtube#video', 'videoId': 'Bmlxp0jRzAc'},
#   'snippet': {'publishedAt': '2022-02-08T13:00:06Z',
#    'channelId': 'UCsspPYzCpmjeStkAlcyK3yg',
#    'title': 'СДЕЛАЛ УДОЧКУ САМ и НАЛОВИЛ РЫБЫ . Зимняя рыбалка, пробую ловить щуку у дома.',
#    'description': 'Мой второй канал: https://www.youtube.com/channel/UCnAqY6NtcENFRyXa1JpOTUw Наконец-то вода пришла, реки ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Bmlxp0jRzAc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Bmlxp0jRzAc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Bmlxp0jRzAc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Always Alone',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T13:00:06Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'uOLq1KDiwVmsMYBpfwiyKMEv0cU',
#   'id': {'kind': 'youtube#video', 'videoId': 'SeyF7bUr-0U'},
#   'snippet': {'publishedAt': '2022-02-08T19:04:22Z',
#    'channelId': 'UCWAK-dRtTEjnQnD96L6UMsQ',
#    'title': 'Зеленский ответил Путину на «терпи, красавица» после встречи с Макроном',
#    'description': 'Подпишитесь на канал РБК: https://www.youtube.com/user/tvrbcnews?sub_confirmation=1 --------------------- Президент ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SeyF7bUr-0U/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/SeyF7bUr-0U/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/SeyF7bUr-0U/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'РБК',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T19:04:22Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'p6afTrZKPLzQtewM-F8yVYXEAlg',
#   'id': {'kind': 'youtube#video', 'videoId': 'ji2DUbpzxq8'},
#   'snippet': {'publishedAt': '2020-10-29T21:00:06Z',
#    'channelId': 'UCWskYkV4c4S9D__rsfOl2JA',
#    'title': '패러다임 변화 주도+높은 진입장벽BI주 중 시가총액 2위 나온다 / 한경 재테크 위크 - 박세익 전무, 김태홍 대표',
#    'description': '김태홍 #박세익 #BBIG #재테크 박세익 인피니티투자자문 전무와 김태홍 그로쓰힐자산운용 대표가 BBIG 중 어떤 종목이 내년에 많이 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ji2DUbpzxq8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ji2DUbpzxq8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ji2DUbpzxq8/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': '한경 글로벌마켓',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-10-29T21:00:06Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'O5QF5TdUk8HzUNXO_G2MjxwaAOc',
#   'id': {'kind': 'youtube#video', 'videoId': '0ub3Fv0VRj8'},
#   'snippet': {'publishedAt': '2022-02-08T11:41:36Z',
#    'channelId': 'UCN6sm8iHiPd0cnoUardDAnw',
#    'title': 'আন্তর্জাতিক সংবাদ | Jamuna I-Desk | 08 February 2022',
#    'description': 'Enjoy and stay connected with us: Subscribe to Jamuna Television on YouTube https://Youtube.com/jamunatvbd Like Jamuna ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0ub3Fv0VRj8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/0ub3Fv0VRj8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/0ub3Fv0VRj8/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Jamuna TV',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T11:41:36Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Ctco1LS7za3s54OSxmtuwy1yO4Y',
#   'id': {'kind': 'youtube#video', 'videoId': 'mVW239Hi8fU'},
#   'snippet': {'publishedAt': '2022-02-08T15:38:59Z',
#    'channelId': 'UCocHtA1ADT6kTObipYzJoww',
#    'title': 'Rocket League Freestyle Pokemon 2',
#    'description': 'Pro Freestyling in Rocket League Pokemon is back! Henkovic, Gappled, OSM, Maktuf, Evo, and Atlas compete in RL Pokemon 2 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mVW239Hi8fU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/mVW239Hi8fU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/mVW239Hi8fU/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'SunlessKhan',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T15:38:59Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Xs-3WOpcrdITjwFlDsRvLj_9iR0',
#   'id': {'kind': 'youtube#video', 'videoId': 'HyfjQcLxwSE'},
#   'snippet': {'publishedAt': '2021-01-26T08:02:50Z',
#    'channelId': 'UC_HCJYWdVXkYtC8loUrMikw',
#    'title': 'Vi hyller kjærligheten - Sjekk ut våre tilbud!',
#    'description': 'Husk morsdag og valentine 14.februar! Vi har gavetips og flere gode tilbud frem til 15.februar.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HyfjQcLxwSE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/HyfjQcLxwSE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/HyfjQcLxwSE/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Bjørklund - Lykkesmed',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-01-26T08:02:50Z'}}]
